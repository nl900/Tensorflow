# %%
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import regularizers

import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

from  IPython import display
from matplotlib import pyplot as plt

import numpy as np

import pathlib
import shutil
import tempfile

logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')
# Out:
# Downloading data from http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz
# 2816407858/2816407858 [==============================] - 904s 0us/step

# %%
FEATURES = 28
ds = tf.data.experimental.CsvDataset(gz,[float(),]*(FEATURES+1), compression_type="GZIP")

# repacks the list of scalars into pairs of feature_vector, label
def pack_row(*row):
  label = row[0]
  features = tf.stack(row[1:],1)
  return features, label

packed_ds = ds.batch(10000).map(pack_row).unbatch() # unpack each batch

N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# split training and validation set
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

validate_ds = validate_ds.batch(BATCH_SIZE) # split to batches
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE) 

# decrease learning rate during training
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  0.001,
  decay_steps=STEPS_PER_EPOCH*1000,
  decay_rate=1,
  staircase=False)

def get_optimizer():
  return tf.keras.optimizers.Adam(lr_schedule)

def get_callbacks(name):
  return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
    tf.keras.callbacks.TensorBoard(logdir/name),
  ]

def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
  if optimizer is None:
    optimizer = get_optimizer()
  model.compile(optimizer=optimizer,
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.metrics.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

  model.summary()

  history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(name),
    verbose=0)
  return history

# %%
tiny_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

size_histories = {}
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')

plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 16)                464
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4927,  binary_crossentropy:0.7312,  loss:0.7312,  val_accuracy:0.4790,  val_binary_crossentropy:0.7149,  val_loss:0.7149,
# ....................................................................................................
# Epoch: 100, accuracy:0.5889,  binary_crossentropy:0.6277,  loss:0.6277,  val_accuracy:0.6050,  val_binary_crossentropy:0.6250,  val_loss:0.6250,
# ....................................................................................................
# Epoch: 200, accuracy:0.6161,  binary_crossentropy:0.6161,  loss:0.6161,  val_accuracy:0.6130,  val_binary_crossentropy:0.6152,  val_loss:0.6152,
# ....................................................................................................
# Epoch: 300, accuracy:0.6258,  binary_crossentropy:0.6104,  loss:0.6104,  val_accuracy:0.6240,  val_binary_crossentropy:0.6119,  val_loss:0.6119,
# ....................................................................................................
# Epoch: 400, accuracy:0.6378,  binary_crossentropy:0.6040,  loss:0.6040,  val_accuracy:0.6240,  val_binary_crossentropy:0.6076,  val_loss:0.6076,
# ....................................................................................................
# Epoch: 500, accuracy:0.6426,  binary_crossentropy:0.5979,  loss:0.5979,  val_accuracy:0.6380,  val_binary_crossentropy:0.6016,  val_loss:0.6016,
# ....................................................................................................
# Epoch: 600, accuracy:0.6511,  binary_crossentropy:0.5921,  loss:0.5921,  val_accuracy:0.6420,  val_binary_crossentropy:0.5967,  val_loss:0.5967,
# ....................................................................................................
# Epoch: 700, accuracy:0.6594,  binary_crossentropy:0.5864,  loss:0.5864,  val_accuracy:0.6560,  val_binary_crossentropy:0.5910,  val_loss:0.5910,
# ....................................................................................................
# Epoch: 800, accuracy:0.6650,  binary_crossentropy:0.5816,  loss:0.5816,  val_accuracy:0.6590,  val_binary_crossentropy:0.5885,  val_loss:0.5885,
# ....................................................................................................
# Epoch: 900, accuracy:0.6724,  binary_crossentropy:0.5785,  loss:0.5785,  val_accuracy:0.6530,  val_binary_crossentropy:0.5873,  val_loss:0.5873,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6751,  binary_crossentropy:0.5761,  loss:0.5761,  val_accuracy:0.6550,  val_binary_crossentropy:0.5855,  val_loss:0.5855,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6763,  binary_crossentropy:0.5736,  loss:0.5736,  val_accuracy:0.6480,  val_binary_crossentropy:0.5863,  val_loss:0.5863,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6778,  binary_crossentropy:0.5715,  loss:0.5715,  val_accuracy:0.6500,  val_binary_crossentropy:0.5846,  val_loss:0.5846,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6828,  binary_crossentropy:0.5699,  loss:0.5699,  val_accuracy:0.6520,  val_binary_crossentropy:0.5851,  val_loss:0.5851,
# ....................................................................................................
# Epoch: 1400, accuracy:0.6841,  binary_crossentropy:0.5684,  loss:0.5684,  val_accuracy:0.6550,  val_binary_crossentropy:0.5848,  val_loss:0.5848,
# ....................................................................................................
# Epoch: 1500, accuracy:0.6828,  binary_crossentropy:0.5669,  loss:0.5669,  val_accuracy:0.6490,  val_binary_crossentropy:0.5854,  val_loss:0.5854,
# ....................................................................................................
# Epoch: 1600, accuracy:0.6813,  binary_crossentropy:0.5660,  loss:0.5660,  val_accuracy:0.6690,  val_binary_crossentropy:0.5835,  val_loss:0.5835,
# ....................................................................................................
# Epoch: 1700, accuracy:0.6853,  binary_crossentropy:0.5651,  loss:0.5651,  val_accuracy:0.6580,  val_binary_crossentropy:0.5839,  val_loss:0.5839,
# ....................................................................................................
# Epoch: 1800, accuracy:0.6877,  binary_crossentropy:0.5641,  loss:0.5641,  val_accuracy:0.6600,  val_binary_crossentropy:0.5843,  val_loss:0.5843,
# ....................................................................................................
# Epoch: 1900, accuracy:0.6869,  binary_crossentropy:0.5635,  loss:0.5635,  val_accuracy:0.6600,  val_binary_crossentropy:0.5844,  val_loss:0.5844,
# .................................................................................
# (0.5, 0.7)

# %%
large_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(1)
])
size_histories['large'] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 512)               14848
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dense_11 (Dense)            (None, 512)               262656
#
#  dense_12 (Dense)            (None, 512)               262656
#
#  dense_13 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5014,  binary_crossentropy:0.8090,  loss:0.8090,  val_accuracy:0.4780,  val_binary_crossentropy:0.6785,  val_loss:0.6785,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0021,  loss:0.0021,  val_accuracy:0.6590,  val_binary_crossentropy:1.7760,  val_loss:1.7760,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0001,  loss:0.0001,  val_accuracy:0.6530,  val_binary_crossentropy:2.3791,  val_loss:2.3791,
# ................

# %%
# large network with L2 weight regularization
# every coeff in the weight matrix layer will add 0.001*weight_coeff_val**2 to the total loss of the network
l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001), 
                 input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 512)               14848
#
#  dense_15 (Dense)            (None, 512)               262656
#
#  dense_16 (Dense)            (None, 512)               262656
#
#  dense_17 (Dense)            (None, 512)               262656
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5087,  binary_crossentropy:0.7835,  loss:2.2878,  val_accuracy:0.5130,  val_binary_crossentropy:0.6759,  val_loss:2.0934,
# ....................................................................................................
# Epoch: 100, accuracy:0.6576,  binary_crossentropy:0.5928,  loss:0.6176,  val_accuracy:0.6800,  val_binary_crossentropy:0.5886,  val_loss:0.6131,
# ....................................................................................................
# Epoch: 200, accuracy:0.6792,  binary_crossentropy:0.5782,  loss:0.6033,  val_accuracy:0.6660,  val_binary_crossentropy:0.5795,  val_loss:0.6045,
# ....................................................................................................
# Epoch: 300, accuracy:0.6854,  binary_crossentropy:0.5703,  loss:0.5976,  val_accuracy:0.6800,  val_binary_crossentropy:0.5787,  val_loss:0.6056,
# ....................................................................................................
# Epoch: 400, accuracy:0.7000,  binary_crossentropy:0.5564,  loss:0.5837,  val_accuracy:0.7050,  val_binary_crossentropy:0.5686,  val_loss:0.5958,
# ....................................................................................................
# Epoch: 500, accuracy:0.7063,  binary_crossentropy:0.5492,  loss:0.5781,  val_accuracy:0.6830,  val_binary_crossentropy:0.5694,  val_loss:0.5983,
# ....................................................................................................
# Epoch: 600, accuracy:0.7036,  binary_crossentropy:0.5475,  loss:0.5778,  val_accuracy:0.6710,  val_binary_crossentropy:0.5745,  val_loss:0.6050,
# ....................................................................................................
# Epoch: 700, accuracy:0.7157,  binary_crossentropy:0.5393,  loss:0.5707,  val_accuracy:0.6840,  val_binary_crossentropy:0.5749,  val_loss:0.6066,
# ........
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0r/9t3m18wd21n_5dp095z1_8km0000gn/T/ipykernel_2588/1390850456.py in <module>
#      14 ])
#      15
# ---> 16 regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
#
# NameError: name 'regularizer_histories' is not defined

# %%
# L2 weight regularization with dropout
# L2: every coeff in the weight matrix layer will add 0.001*weight_coeff_val**2 to the total loss of the network
# dropout: randomly ignore some layer outputs to encourage the network to learn a sparse representation
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])
regularizer_histories = {}
regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 512)               14848
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_21 (Dense)            (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_22 (Dense)            (None, 512)               262656
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_23 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5022,  binary_crossentropy:0.7948,  loss:0.9530,  val_accuracy:0.5540,  val_binary_crossentropy:0.6699,  val_loss:0.8272,
# ....................................................................................................
# Epoch: 100, accuracy:0.6461,  binary_crossentropy:0.6035,  loss:0.6321,  val_accuracy:0.6660,  val_binary_crossentropy:0.5837,  val_loss:0.6120,
# ....................................................................................................
# Epoch: 200, accuracy:0.6602,  binary_crossentropy:0.5892,  loss:0.6152,  val_accuracy:0.6820,  val_binary_crossentropy:0.5809,  val_loss:0.6069,
# ....................................................................................................
# Epoch: 300, accuracy:0.6663,  binary_crossentropy:0.5824,  loss:0.6108,  val_accuracy:0.6810,  val_binary_crossentropy:0.5684,  val_loss:0.5968,
# ....................................................................................................
# Epoch: 400, accuracy:0.6760,  binary_crossentropy:0.5744,  loss:0.6046,  val_accuracy:0.6800,  val_binary_crossentropy:0.5568,  val_loss:0.5871,
# ....................................................................................................
# Epoch: 500, accuracy:0.6785,  binary_crossentropy:0.5704,  loss:0.6029,  val_accuracy:0.6940,  val_binary_crossentropy:0.5463,  val_loss:0.5789,
# ....................................................................................................
# Epoch: 600, accuracy:0.6846,  binary_crossentropy:0.5642,  loss:0.5985,  val_accuracy:0.6880,  val_binary_crossentropy:0.5454,  val_loss:0.5798,
# ....................................................................................................
# Epoch: 700, accuracy:0.6879,  binary_crossentropy:0.5634,  loss:0.5992,  val_accuracy:0.7000,  val_binary_crossentropy:0.5540,  val_loss:0.5898,
# ....................................................................................................
# Epoch: 800, accuracy:0.6917,  binary_crossentropy:0.5584,  loss:0.5955,  val_accuracy:0.6950,  val_binary_crossentropy:0.5439,  val_loss:0.5811,
# ....................................................................................................
# Epoch: 900, accuracy:0.6945,  binary_crossentropy:0.5534,  loss:0.5917,  val_accuracy:0.6990,  val_binary_crossentropy:0.5401,  val_loss:0.5784,
# ....................................................................................................
# Epoch: 1000, accuracy:0.7032,  binary_crossentropy:0.5457,  loss:0.5853,  val_accuracy:0.6800,  val_binary_crossentropy:0.5525,  val_loss:0.5922,
# ......................................................................
# (0.5, 0.7)
